# %%
import os
import io
import base64
from PIL import Image

# %%
path = "C:\\Users\\GirrajJangid\\jupyter notebook\\Machine Learning projects\\TextExtractor\\images"

# %%
for i, filename in enumerate(os.listdir(path)):
    os.rename("C:\\Users\\GirrajJangid\\jupyter notebook\\Machine Learning projects\\TextExtractor\\images\\" + filename , 
             "C:\\Users\\GirrajJangid\\jupyter notebook\\Machine Learning projects\\TextExtractor\\images\\" + str(i) + ".jpeg")

# %%
# base64 images

# %%
img = "data:image/png;base64,..."

# %%
img = img.split(',')

# %%
len(img[1]) # 647972
# Out:
# 647972

# %%
base64.encodestring(img[1])
# Out:
# C:\Users\GirrajJangid\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: encodestring() is a deprecated alias since 3.1, use encodebytes()
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\GirrajJangid\Anaconda3\lib\base64.py in _input_type_check(s)
#     516     try:
# --> 517         m = memoryview(s)
#     518     except TypeError as err:
#
# TypeError: memoryview: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-7545bcb29089> in <module>()
# ----> 1 base64.encodestring(img[1])
#
# C:\Users\GirrajJangid\Anaconda3\lib\base64.py in encodestring(s)
#     545                   "use encodebytes()",
# ...

# %%
#base64.b64encode(img[1])

# %%
# It extract data from string and convert them into an Image
with open('base24_2.txt','r') as fl:
    str1 = fl.read()
    
img = Image.open(io.BytesIO(base64.decodestring(str1.split(',')[1].encode())))
# Out:
# C:\Users\GirrajJangid\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: decodestring() is a deprecated alias since Python 3.1, use decodebytes()
#   after removing the cwd from sys.path.

# %% [markdown]
# # It load dates from text file

# %%
def load_dataset():
    with open("all_image_dates.txt") as file:
        data = file.read()
    data = pd.DataFrame(data.replace(';','').split('\n'),index = range(1,596),columns = ['actual'])
    data['converted'] = None
    for i in data.actual[data.actual != 'null'].items():
        data.loc[i[0],'converted'] = parse(i[1]).strftime('%Y-%m-%d')    
    return data

# %%
data = load_dataset()
data.head()
