# %% [markdown]
# # Preprocessing terms
#
# 1. Scaling to the right size
# 2. Increase contrast
# 3. Binarize image
# 4. remove noise and scanning artefacts (black border)
# 5. Deskew
# 6. Remove border

# %%
import re
import cv2
import glob
import imutils
import tempfile
import argparse
import dateparser
import numpy as np
import pandas as pd
from PIL import Image
import pytesseract as pt
from imutils import contours
from datefinder import find_dates
from dateutil.parser import parse
from matplotlib import pyplot as plt
from scipy.spatial import distance as dist
from dateparser.search import search_dates
from imutils.perspective import four_point_transform
pt.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %%
def spread(arg):
    ret = []
    for i in arg:
        if isinstance(i, list):
            ret.extend(i)
        else:
            ret.append(i)
    return ret

def deep_flatten(lst):
    result = []
    result.extend(spread(list(map(lambda x: deep_flatten(x) if type(x) == list else x, lst))))
    return result

# %%
def finding_date(img_str):
    
    imstr = img_str
    pattern1 = r"(\d{1,4}([.'’\-/])\d{1,2}([.'’\-/])\d{1,4})"
    pattern2 = r"(\d{1,4}([.'’\-/\s])[ADFJMNOSadfjmnos]\w*([.'’\-/\s]*)\d{1,4})"
    pattern3 = r"([ADFJMNOSadfjmnos]\w*\s\d{1,4}([,'’.\-/\s]*)([.'’\-/\s])\d{1,4})"
    pattern4 = r"[ADFJMNOSadfjmnos]\w*\d{1,4}(['’]*)\d{1,4}"
    pattern5 = r"(\d{1,4}([.'’\-/\s])\d{1,4}"
    
    date_find = []

    for i in imstr:
        for j in (re.search(regex,i) for regex in [pattern1, pattern2, pattern3, pattern4]):
            if j:
                s = j.group()
                if s.find('.'):
                    date_find.append("-".join(s.split('.')))
                else:
                    date_find.append(s)

    date_find = list(set(date_find))

    dates = []
    for i in date_find:
        try:
            i = i.replace("’","'")
            i = i.replace("’’","'")
            i = i.replace('"',"'")
            i = parse(i).strftime("%Y-%m-%d")
            if 2010 < int(i[:4]) < 2020:
                dates.append(i)   
        except:
            continue
    
    if dates:
        return max(dates)
    return None

# %% [markdown]
# # Instead of feeding single input image with pre-process.
# # Now, I'm going to feed more than 4 same image with differently pre-processed.Also called Stacking technique

# %%
def globalpreprocess(path):
    
    img_str_1 = pt.image_to_string(path, lang='eng')
    
    gaussian_filter = (5,5)
    img = cv2.imread(path) 
    img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)
    img_str_2 = pt.image_to_string(Image.fromarray(img_blur),lang ="eng")
    
    img_ad_thres = cv2.adaptiveThreshold(img_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    img_str_3 = pt.image_to_string(Image.fromarray(img_ad_thres),lang='eng')

    ret,th1 = cv2.threshold(img_blur, 100, 225, cv2.THRESH_BINARY)
    img_str_4 = pt.image_to_string(Image.fromarray(th1), lang = 'eng')

    return [img_str_1,img_str_2,img_str_3,img_str_4]

# %%
path = 'images/13.jpeg'

# %%
ll = globalpreprocess(path)

# %%
print(ll[0])
# Out:
# GENESIS S FoopS PL! PLATTER
# GST *SaALBPSOT 32K ZL
#
# BILL NO: 206 DT: 25/07/19 13: 49=
#
# FRIED RICE
# {PL
#
# SWEET LASSI
# 1PL
#
# SPECIAL HEAL
# PL

# %%
path = 'images/1.jpeg'
config = ("-l eng --oem 1 --psm 3")

# %%
# 1. Without any filter
print(pt.image_to_string(path, lang='eng', config = config))
# Out:
# $3.00
#
# $5100
# $275
#
# rourtan Sods
#
# $33.75

# %%
# 2. with filter
# image < resize < grayscale < gaussian 
gaussian_filter = (5,5)
img = cv2.imread(path) 
image = cv2.resize(img, None, fx=4, fy=4, interpolation=cv2.INTER_CUBIC) 
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, gaussian_filter, 0)
print(pt.image_to_string(Image.fromarray(blurred),lang = "eng", config = config))
# Out:
# (\ nV« >
# WQS
#
# case Rubio cafe
#
# 25-17 Astoria Blvd
# ia, NY 11102
#
# Ticket: T?
# FOR peeERT
#
# Grilled Skirt Steak
# Wel done
#
# Fountain Sodas
#
# Subtotal
#
# Sale Tax
# ESS eee
#
# Total

# %%
# 3. with filter
kernel = np.ones((2, 2), np.uint8)
img_dilate = cv2.dilate(gray, kernel, iterations=1)
img_erode = cv2.erode(img_dilate, kernel, iterations=1)
img_gauss = cv2.GaussianBlur(img_erode, gaussian_filter, 0)

# Thresholding
img_thres = cv2.adaptiveThreshold(img_gauss, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)

print(pt.image_to_string(Image.fromarray(img_thres),lang='eng', config = config))

# %%
# 4. with filters
# image < resize < grayscale < gaussian < Binarization(threshold)
ret,th1 = cv2.threshold(img_thres,100,225,cv2.THRESH_BINARY)
ret2,th2 = cv2.threshold(img_gauss,100,220,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
print(pt.image_to_string(Image.fromarray(th1), lang = 'eng', config = config))

# %%
def save_df(df):
    df.to_csv('image_data.csv',header=True,index=False)

# %%
raw = pd.read_csv('image_data.csv')

# %%
raw['predicted'] = None

# %%
def globalfindingdate(path):
    config = ("-l eng --oem 1 --psm 3")
    gaussian_filter = (3,3)
    img = cv2.imread(path) 
    img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)
    img_str_2 = pt.image_to_string(Image.fromarray(img_blur),lang ="eng",config=config)
    img_str_2 = list(set(map(lambda x : x.strip(), img_str_2.split('\n'))))
    date = finding_date(img_str_2)
    if date:
        print('First: ',date)
        return date
    
    img_str_1 = pt.image_to_string(path, lang='eng',config=config)
    img_str_1 = list(set(map(lambda x : x.strip(), img_str_1.split('\n'))))
    date = finding_date(img_str_1)
    if date:
        print('Second: ',date)
        return date 
    
    ret,th1 = cv2.threshold(img_blur, 100, 225, cv2.THRESH_BINARY)
    img_str_4 = pt.image_to_string(Image.fromarray(th1), lang = 'eng',config=config)
    img_str_4 = list(set(map(lambda x : x.strip(), img_str_4.split('\n'))))
    date = finding_date(img_str_4)
    if date:
        print('Third: ',date)
        return date 
    
    img_ad_thres = cv2.adaptiveThreshold(img_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    img_str_3 = pt.image_to_string(Image.fromarray(img_ad_thres),lang='eng',config=config)
    img_str_3 = list(set(map(lambda x : x.strip(), img_str_3.split('\n'))))
    date = finding_date(img_str_3)
    if date:
        print('Forth: ',date)
        return date 
    print('[]')
    return None

# %%
def globalpreprocess(path):
    
    img_str_1 = pt.image_to_string(path, lang='eng')
    
    gaussian_filter = (3,3)
    img = cv2.imread(path) 
    img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)
    img_str_2 = pt.image_to_string(Image.fromarray(img_blur),lang ="eng")
    
    #img_ad_thres = cv2.adaptiveThreshold(img_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    #img_str_3 = pt.image_to_string(Image.fromarray(img_ad_thres),lang='eng')

    #ret,th1 = cv2.threshold(img_blur, 100, 225, cv2.THRESH_BINARY)
    #img_str_4 = pt.image_to_string(Image.fromarray(th1), lang = 'eng')

    return [img_str_1,img_str_2]

# %%
path = 'images/91.jpeg'
globalfindingdate(path)

# %%
z =list(set(map(lambda x: x.strip(),ll[0].split('\n'))))

finding_date(z)
# Out:
# '2019-07-25'

# %%
raw['predicted_3'] = None

# %%
for i in raw[raw.converted.notnull()].index:
    path = "images/" + str(i+1) + ".jpeg"
    print(i+1,end='  ')
    date = globalfindingdate(path)
    raw.loc[i,'predicted_3'] = date
# Out:
# 1  []
# 2  Second:  2019-07-25
# 3  First:  2018-09-29
# 4  First:  2019-10-06
# 5  First:  2019-05-29
# 6  First:  2019-07-03
# 8  []
# 9  []
# 10  First:  2019-05-22
# 11  First:  2019-07-17
# 12  First:  2019-07-02
# 13  []
# 14  []
# 15  []
# 16  []
# 17  First:  2019-05-24
# 18  Third:  2016-04-15
# 19  First:  2019-07-20
# 20  First:  2019-06-20
# 21  First:  2019-05-29
# 22  []
# 23  []
# 24  []
# 25  First:  2013-06-28
# 26  Second:  2019-06-03
# 27  First:  2019-06-20
# 28  First:  2019-07-12
# 29  First:  2019-06-07
# 30  First:  2019-06-28
# 31  First:  2019-04-30
# 32  []
# 33  []
# 34  First:  2019-06-08
# 35  First:  2019-07-14
# 36  First:  2018-06-30
# 37  First:  2019-06-27
# 38  []
# 39  First:  2016-11-24
# 41  Second:  2019-06-19
# 42  First:  2019-06-20
# 43  First:  2019-05-19
# 45  First:  2019-05-18
# 46  First:  2014-05-22
# 47  []
# 48  First:  2015-08-22
# 49  First:  2019-08-09
# 50  []
# 52  First:  2019-05-22
# 54  Second:  2019-06-01
# 55  First:  2019-07-09
# 56  Third:  2019-07-06
# 59  First:  2018-10-20
# 60  First:  2018-02-17
# 61  []
# 62  First:  2019-06-06
# 64  First:  2019-06-01
# 66  First:  2019-07-04
# 67  First:  2016-11-08
# 68  Second:  2019-06-01
# 69  First:  2019-06-28
# 71  First:  2019-06-14
# 72  First:  2019-06-25
# 73  Third:  2019-06-19
# 74  First:  2019-11-07
# 75  First:  2019-04-08
# 76  Second:  2019-07-01
# 77  []
# 79  []
# 80  Third:  2019-02-05
# 81  First:  2019-03-02
# 82  First:  2019-03-18
# 83  Forth:  2018-07-24
# 85  First:  2016-05-26
# 86  First:  2019-06-29
# 88  First:  2019-05-17
# 89  First:  2019-07-01
# 90  []
# 91  []
# 92  First:  2019-08-30
# 93  First:  2019-06-04
# 94  Third:  2015-04-25
# 95  First:  2019-07-02
# 96  First:  2019-06-15
# 98  First:  2019-07-03
# 99  First:  2017-12-02
# 100  Third:  2019-07-18

# %%
val = (raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).values
ind = (raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).index

# %%
print((raw.converted == raw.predicted).value_counts())
print((raw.converted == raw.predicted_2).value_counts())
print((raw.converted == raw.predicted_3).value_counts())
# Out:
# False    51
# True     49
# dtype: int64
# True     54
# False    46
# dtype: int64
# True     54
# False    46
# dtype: int64

# %%
(54/86)*100
# Out:
# 62.7906976744186

# %% [markdown]
# # 4th attempt 63% accuracy

# %%
for i,j in enumerate(val):
    if not j:
        print(ind[i])
# Out:
# 0
# 3
# 7
# 8
# 12
# 13
# 14
# 15
# 17
# 19
# 21
# 22
# 23
# 24
# 27
# 31
# 32
# 37
# 46
# 49
# 54
# 55
# 60
# 65
# 66
# 68
# 72
# 76
# 78
# 79
# 81
# 82
# 89
# 90
# 93
# 97
# 99

# %%
print((raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).value_counts())
print((raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted_2).value_counts())
# Out:
# True     49
# False    37
# dtype: int64
# True     54
# False    32
# dtype: int64

# %%
(54/86)*100
# Out:
# 62.7906976744186

# %% [markdown]
# # 3rd attempt accuracy is 60%

# %%
def order_points(pts):
    pts = pts.reshape(4,2)
    # sort the points based on their x-coordinates
    xSorted = pts[np.argsort(pts[:, 0]), :]

    # grab the left-most and right-most points from the sorted
    # x-roodinate points
    leftMost = xSorted[:2, :]
    rightMost = xSorted[2:, :]

    # now, sort the left-most coordinates according to their
    # y-coordinates so we can grab the top-left and bottom-left
    # points, respectively
    leftMost = leftMost[np.argsort(leftMost[:, 1]), :]
    (tl, bl) = leftMost

    # now that we have the top-left coordinate, use it as an
    # anchor to calculate the Euclidean distance between the
    # top-left and right-most points; by the Pythagorean
    # theorem, the point with the largest distance will be
    # our bottom-right point
    D = dist.cdist(tl[np.newaxis], rightMost, "euclidean")[0]
    (br, tr) = rightMost[np.argsort(D)[::-1], :]

    # return the coordinates in top-left, top-right,
    # bottom-right, and bottom-left order
    return np.array([tl, tr, br, bl], dtype="float32")

# %%
def four_point_transform(image, pts):
    # obtain a consistent order of the points and unpack them
    # individually
    rect = order_points(pts)
    (tl, tr, br, bl) = rect

    # compute the width of the new image, which will be the
    # maximum distance between bottom-right and bottom-left
    # x-coordiates or the top-right and top-left x-coordinates
    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))

    # compute the height of the new image, which will be the
    # maximum distance between the top-right and bottom-right
    # y-coordinates or the top-left and bottom-left y-coordinates
    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))

    # now that we have the dimensions of the new image, construct
    # the set of destination points to obtain a "birds eye view",
    # (i.e. top-down view) of the image, again specifying points
    # in the top-left, top-right, bottom-right, and bottom-left
    # order
    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype="float32")

    # compute the perspective transform matrix and then apply it
    M = cv2.getPerspectiveTransform(rect, dst)
    warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))

    # return the warped image
    return warped

# %%
img = cv2.imread(path) 
img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
gaussian_filter = (3,3)
kernel = np.ones((2, 2), np.uint8)
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_dilate = cv2.dilate(img_gray, kernel, iterations=1)
img_erode = cv2.erode(img_dilate, kernel, iterations=1)
img_gauss = cv2.GaussianBlur(img_erode, gaussian_filter, 0)

edged = cv2.Canny(img_gauss, 0, 50)
(contours, _) = cv2.findContours(edged, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours = sorted(contours, key=cv2.contourArea, reverse=True)

for c in contours:
    p = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * p, True)

    if len(approx) == 4:
        target = approx
        break

# %%
Image.fromarray(four_point_transform(img_gauss,target))
# Out:
# <PIL.Image.Image image mode=L size=89x39 at 0x2C3DDCDBD30>

# %%
path = "images/1.jpeg"
gaussian_filter = (3,3)
img = cv2.imread(path) 
img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)    
edged = cv2.Canny(img_blur, 0, 50)
orig_edged = edged.copy()

# find the contours in the edged image, keeping only the
# largest ones, and initialize the screen contour
(contours, _) = cv2.findContours(edged, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours = sorted(contours, key=cv2.contourArea, reverse=True)

# get approximate contour
for c in contours:
    p = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * p, True)

    if len(approx) == 4:
        target = approx
        break

# %%
Image.fromarray(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=1014x1350 at 0x2C3DDCDB8D0>

# %%
imz = Image.fromarray(four_point_transform(img_gray,target))

# %%
imz
# Out:
# <PIL.Image.Image image mode=L size=111x83 at 0x2C3DDCDBEF0>

# %%
print(pt.image_to_string(imz))

# %%
print(pt.image_to_string(Image.fromarray(img_blur)))
# Out:
# c
#
# FOR HERE
#
# Grilled Skirt Steak
# Wel done
#
# Fountain Sodas
#
# Subtotal
#
# Sale Tax
# OS
#
# Total

# %%
ret,th1 = cv2.threshold(four_point_transform(img_blur,target),100,225,cv2.THRESH_BINARY)
print(pt.image_to_string(Image.fromarray(th1), lang = 'eng'))

# %%
temp = raw[raw.converted.notnull()]

# %%
(temp.converted == temp.predicted).value_counts()

# %%
import tensorflow.keras as tf
# Out:
# C:\Users\GirrajJangid\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
imgz  = (tf.applications.vgg16.preprocess_input(img_blur))

# %%
#np.dtype(imgz,np.uint8)
#print(pt.image_to_string(imgz))
import tensorflow as tt

# %%
cv2.imshow('imgz',imgz)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(pt.image_to_string(Image.fromarray(np.apply_along_axis(np.uint8,1,imgz)),lang='eng'))
# Out:
# S91UAKol
#
# ITOW
#
#
#
# A ‘
# a?
# Man
# WIN
# ¥O! AV
# ZOL AVI
# lal

# %%
raw.drop('converted',inplace=True,axis=1)

# %%
raw.head(40)
# Out:
#           actual   converted   predicted predicted_2 predicted_3
# 0   May 21, 2019  2019-05-21         NaN         NaN        None
# 1       25-07-19  2019-07-25  2019-07-25  2019-07-25  2019-07-25
# 2   Sep 29, 2018  2018-09-29  2018-09-29  2018-09-29  2018-09-29
# 3      Oct06' 16  2016-10-06  2019-10-06  2019-10-06  2019-10-06
# 4      5/29/2019  2019-05-29  2019-05-29  2019-05-29  2019-05-29
# 5      03-Jul-19  2019-07-03  2019-07-03  2019-07-03  2019-07-03
# 6            NaN         NaN         NaN         NaN        None
# 7       23-05-19  2019-05-23         NaN         NaN        None
# 8       07-01-19  2019-07-01         NaN         NaN        None
# 9       22-05-19  2019-05-22  2019-05-22  2019-05-22  2019-05-22
# 10    07/17/2019  2019-07-17  2019-07-17  2019-07-17  2019-07-17
# 11      07-02-19  2019-07-02  2019-07-02  2019-07-02  2019-07-02
# 12      02-08-15  2015-02-08         NaN         NaN        None
# 13     22-Jul-19  2019-07-22         NaN         NaN        None
# 14    07/22/2019  2019-07-22         NaN         NaN        None
# 15      06-07-19  2019-06-07         NaN         NaN        None
# 16     5/24/2019  2019-05-24  2019-05-24  2019-05-24  2019-05-24
# 17       4/15/16  2016-04-15         NaN  2016-04-15  2016-04-15
# 18      20-07-19  2019-07-20  2019-07-20  2019-07-20  2019-07-20
# 19     5/20/2019  2019-05-20  2019-06-20  2019-06-20  2019-06-20
# 20     29-May-19  2019-05-29  2019-05-29  2019-05-29  2019-05-29
# 21    22.05.2019  2019-11-22         NaN         NaN        None
# 22      05-07-19  2019-05-07         NaN         NaN        None
# 23      18-06-19  2019-06-18         NaN         NaN        None
# 24     28-Jun-19  2019-06-28  2013-06-28  2013-06-28  2013-06-28
# 25     03-Jun-19  2019-06-03  2019-06-03  2019-06-03  2019-06-03
# 26      06/20/19  2019-06-20  2019-06-20  2019-06-20  2019-06-20
# 27      04-10-19  2019-04-10  2019-07-12  2019-07-12  2019-07-12
# 28     07-Jun-19  2019-06-07  2019-06-07  2019-06-07  2019-06-07
# 29     6/28/2019  2019-06-28  2019-06-28  2019-06-28  2019-06-28
# 30      30-04-19  2019-04-30  2019-04-30  2019-04-30  2019-04-30
# 31      25-07-19  2019-07-25         NaN         NaN        None
# 32      03-10-17  2017-03-10         NaN         NaN        None
# 33      06-08-19  2019-06-08  2019-06-08  2019-06-08  2019-06-08
# 34      14-07-19  2019-07-14  2019-07-14  2019-07-14  2019-07-14
# 35     30-Jun-18  2018-06-30  2018-06-30  2018-06-30  2018-06-30
# 36      06/27/19  2019-06-27  2019-06-27  2019-06-27  2019-06-27
# 37    06/25/2019  2019-06-25         NaN         NaN        None
# 38     24-Nov-16  2016-11-24  2016-11-24  2016-11-24  2016-11-24
# 39           NaN         NaN         NaN         NaN        None
