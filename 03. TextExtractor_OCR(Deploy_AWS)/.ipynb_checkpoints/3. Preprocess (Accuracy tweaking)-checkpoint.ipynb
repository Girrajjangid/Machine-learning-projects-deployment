# %% [markdown]
# # Preprocessing terms
#
# 1. Scaling to the right size
# 2. Increase contrast
# 3. Binarize image
# 4. remove noise and scanning artefacts (black border)
# 5. Deskew
# 6. Remove border

# %%
import re
import cv2
import glob
import imutils
import tempfile
import argparse
import dateparser
import numpy as np
import pandas as pd
from PIL import Image
import pytesseract as pt
from imutils import contours
from datefinder import find_dates
from dateutil.parser import parse
from matplotlib import pyplot as plt
from scipy.spatial import distance as dist
from dateparser.search import search_dates
import imutils.perspective as ip
pt.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %%
def spread(arg):
    ret = []
    for i in arg:
        if isinstance(i, list):
            ret.extend(i)
        else:
            ret.append(i)
    return ret

def deep_flatten(lst):
    result = []
    result.extend(spread(list(map(lambda x: deep_flatten(x) if type(x) == list else x, lst))))
    return result

# %%
def finding_date(img_str):
    
    imstr = img_str
    pattern1 = r"(\d{1,4}([.'’\-/])\d{1,2}([.'’\-/])\d{1,4})"
    pattern2 = r"(\d{1,4}([.'’\-/\s])[ADFJMNOSadfjmnos]\w*([.'’\-/\s]*)\d{1,4})"
    pattern3 = r"([ADFJMNOSadfjmnos]\w*\s\d{1,4}([,'’.\-/\s]*)([.'’\-/\s])\d{1,4})"
    pattern4 = r"[ADFJMNOSadfjmnos]\w*\d{1,4}(['’]*)\d{1,4}"
    pattern5 = r"(\d{1,4}([.'’\-/\s])\d{1,4}"
    
    date_find = []

    for i in imstr:
        for j in (re.search(regex,i) for regex in [pattern1, pattern2, pattern3, pattern4]):
            if j:
                s = j.group()
                if s.find('.'):
                    date_find.append("-".join(s.split('.')))
                else:
                    date_find.append(s)

    date_find = list(set(date_find))

    dates = []
    for i in date_find:
        try:
            i = i.replace("’","'")
            i = i.replace("’’","'")
            i = i.replace('"',"'")
            i = parse(i).strftime("%Y-%m-%d")
            if 2010 < int(i[:4]) < 2020:
                dates.append(i)   
        except:
            continue
    
    if dates:
        return max(dates)
    return None

# %% [markdown]
# # Instead of feeding single input image with pre-process.
# # Now, I'm going to feed more than 4 same image with differently pre-processed.Also called Stacking technique

# %%
def globalpreprocess(path):
    
    img_str_1 = pt.image_to_string(path, lang='eng')
    
    gaussian_filter = (5,5)
    img = cv2.imread(path) 
    img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)
    img_str_2 = pt.image_to_string(Image.fromarray(img_blur),lang ="eng")
    
    img_ad_thres = cv2.adaptiveThreshold(img_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    img_str_3 = pt.image_to_string(Image.fromarray(img_ad_thres),lang='eng')

    ret,th1 = cv2.threshold(img_blur, 100, 225, cv2.THRESH_BINARY)
    img_str_4 = pt.image_to_string(Image.fromarray(th1), lang = 'eng')

    return [img_str_1,img_str_2,img_str_3,img_str_4]

# %%
path = 'images/22.jpeg'

# %%
ll = globalpreprocess(path)

# %%
print(ll[0])

# %%
path = 'images/16.jpeg'
config = ("-l eng --oem 1 --psm 3")

# %%
# 1. Without any filter
print(pt.image_to_string(path, lang='eng', config = config))

# %%
# 2. with filter
# image < resize < grayscale < gaussian 
gaussian_filter = (3,3)
img = cv2.imread(path) 
image = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, gaussian_filter, 0)
print(pt.image_to_string(Image.fromarray(blurred),lang = "eng", config = config))

# %%
# 3. with filter
kernel = np.ones((2, 2), np.uint8)
img_dilate = cv2.dilate(gray, kernel, iterations=1)
img_erode = cv2.erode(img_dilate, kernel, iterations=1)
img_gauss = cv2.GaussianBlur(img_erode, gaussian_filter, 0)

# Thresholding
img_thres = cv2.adaptiveThreshold(img_gauss, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)

print(pt.image_to_string(Image.fromarray(img_thres),lang='eng', config = config))
# Out:
# 2 a k
# * 2 a ort 4 r : i “? .
# 4 . I eT A See, TIT ee NS
# LS by ieee mined sew oe ass LNA. aS
#
# ? ey
#
#
#
#
#
#
#
#
#
#
#
#
#
# :. eee: no a itu “g's og, coe ee ony et un mete eee uo WAS! ~
# See Natohalihlehwavszauthorinvel india. ay
#
# | “A, Wanadvarn Paani ede rola Paiitd,
# | TOM (1828s 66081 (978/800)AN ion Hi08)
#
# | Seb ION AO. 7BOKM onNHA0B,
# ey -  GSTROSAANCS 262 7127; 7',SAC2996742'
#
# * 4
# er ten
# 4
#
#
#
#
#
#
# oh tens yO Ri teat yagi oer : MPa aene ne . a. ay
# Seeree| LSKStINe) 3: i vASs05 15080" x
# recived! = Eooth & Operator’ + 069200334)
# SGZSRA) Ostet Tine + 22.05,2019 3819
# oe rn
# Ee TVijme vaie lh yetvaiate Peay: VAMP ete glee
# petee'y  dyperorveliicle : Car fusenivan
# ese) — ‘Typetof vourney, # Single
# S eo ae ‘ t 4 = + vegan Sane e Nee Got Seat th ae
# ec a) TOIT Fees. v Rs 55
# : Ge aS iw hea eS ee ai a De ee oe
# - Netoe RR . eT ee Slane Se res ode
#
# vay, OM, For OvetloadedWehicle
# , Standard Weight of Vehleles 0 RE
# > Actdal Weiont of Mehiels: mee
#
# BS:
#
#
#
# ‘(Ovenweight: Vetiicie ‘Fees; <BR
#
# Foe se AT es
#
#
#
#
# mt
# —_ == we
#
#
#
# 2 NY teenies wet er eee epee ecient Wee ee
# ODN UPL teh RB RI ace ro otprietnce mae
# Set] yishfYouiSafg ® Happy. Uouriiey
# He: werk , Hish MOU Te, (o apR ye OUPREY
#
# °F : y :
# / - 4 ‘2 (3 ’ ; , . / .
# Tied ty, Ay ”
#
# : bp
#
#
#
#
#
#
#
#
#
# ww a SE Se hee 3
# eg, wears ~ wget te we TAL Et 2 MRS Does
# -« ™ “wre Te : % pe A ee fe ee |
# She wee A Ary = ry ag
# is Padre HON ON. my pet Me Ton
# , : 7 La ay © ba. a ~ a 1 ‘i »
# INS OS Sate By as In
#
# aC 22
# ae. Ey ats = . +o % Loman’
# eT AG TAP EG ST oa eR ee ING ONE
# ota RE Me ET Mees ITB My ara
#
# .., a, ao “4, rq ; . i
# < EN a de A A gh a ae

# %%
# 4. with filters
# image < resize < grayscale < gaussian < Binarization(threshold)
ret,th1 = cv2.threshold(img_thres,100,225,cv2.THRESH_BINARY)
ret2,th2 = cv2.threshold(img_thres,0,220,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#print(pt.image_to_string(Image.fromarray(th1), lang = 'eng', config = config))
Image.fromarray(img_thres)
# Out:
# <PIL.Image.Image image mode=L size=2160x2880 at 0x2B33011A128>

# %%
kernel = np.ones((5, 5), np.uint8)
img_dilate = cv2.dilate(th1, kernel, iterations=1)
img_erode = cv2.erode(img_dilate, kernel, iterations=1)
img_gauss = cv2.GaussianBlur(img_erode, gaussian_filter, 0)
print(pt.image_to_string(Image.fromarray(img_gauss)))
# Out:
# a,t a) wh
#
# ‘: et sote aa, 7 hte w= owe ete 1: Aw ase eS
# Ate NS ES eR NG Ee ARES TEN NS
# ‘ at ay este yet. OTe ta PNT
#
# OL ol ’ L
#
# pane Bd Pg he, GW. Ke Re Fe ee er NS a ey yA em ae et ON ee
# OTS eh eee "Wh “> “wes A WOR SS My netatan. sy = wet K 3 aa “eNt3 eee oe *,
# s
#
# > e wages
# wate 788 aE,
# wrsiyph WAZ Sara
#
# - Mo Nt al ee ay ays “yf " “"
#
#
#
# %
# ig
# {2
#
#
#
# orate
# my eh 8
# %2 e°"2",
#
# une, * An
#
# Ane
# a’ Yon
# a ¢ > Nr
# Ree Sra ageete tyes 2 ee : : ooo
# i eee atonal highways Authorin af ingi3- Bete ee a:
# Tit ye, eee “/ wa ramangers Seawae U4-C£ Tollway Pet. bed" i‘ ditt ae
# ; fA." pe hte
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# me “yt, Toll P.lazé :Gegal (3781800; KM on .id-03) aS
# Wey Section: 46.780KM on: HH-08, - ER
# Sa: “4 «- GST=OSAANCS2627H12T / Sat-966747 ae
# eee cae ee ENG 6
# aie Ticket no : dF 145360513080 PIRES
# Lee gee Booth eae tor : 08-0033 Biot GRE
# pace caval. Date @-Tine + 22.05;2019-1319 rene
# EG EBS oe + 42.09;2013 13319 ee
# meta Roget Venicle’ Ho. | » 4FU0. . Ne
# petcay Typevof Vehicle : Car/Jeen/Var Sain
# ese] — “Typetof Journey * Single oie
# cess a Todd Fee 7 Rs 55 SNe ae
# pre Se seolee anlatreletarieries fee seein aston eet tee oh tos et ee ee HP wrt
# Ces 2 6G bilan hen OD) na cu Das -
# i nag Only for Overloaded. Vehicle | Re eee
# ek Ss tegt tee ; Fy a fa dee’
# a, Standard Weigrit. of Venicle: 0 kG sec
# rae fy’: . ' . ® a .° . ' im: ‘ “. 7
# Wg hE Actual Weight of Vehicle: .S.KG AS
# f. 2eur at "ms ef" 7 "ote. 9" oe . ~ ff : -"
# fae Overweight: Yehicie Fees: ; Rs.0 Te ee
#
#
#
#
#
#
#
#
# - Bote! .. wie blige ieee ems bo -
#
# ot " . ~ a , ees ‘o - . a nn . ray 8 At ~
# Go! Wish You Safe & Hapsy Journey HgNe OS
# ard teens -* vot ae —
# ys ‘3 , <S .
# ete, ES
#
# yea be eB o
# NE - cea
# _ e asy va “ = 7 i =e: : “ os a = “5h F *s, . " rt i pS rit
# Ne ats ri uy mt Oty cm eee sO - suctee. . tabs NS i SSS ¢. f
# Shoe ee oak Sy sa BS REPS 52 SOR
#
# . fs =. ro . nt
#
# °f
#
# vt 7 as Vy Sv arcs

# %%
def save_df(df):
    df.to_csv('image_data.csv',header=True,index=False)

# %%
raw = pd.read_csv('image_data.csv')

# %%
raw.head(40)
# Out:
#           actual   converted   predicted predicted_2 predicted_3
# 0   May 21, 2019  2019-05-21         NaN         NaN         NaN
# 1       25-07-19  2019-07-25  2019-07-25  2019-07-25  2019-07-25
# 2   Sep 29, 2018  2018-09-29  2018-09-29  2018-09-29  2018-09-29
# 3      Oct06' 16  2016-10-06  2019-10-06  2019-10-06  2019-10-06
# 4      5/29/2019  2019-05-29  2019-05-29  2019-05-29  2019-05-29
# 5      03-Jul-19  2019-07-03  2019-07-03  2019-07-03  2019-07-03
# 6            NaN         NaN         NaN         NaN         NaN
# 7       23-05-19  2019-05-23         NaN         NaN         NaN
# 8       07-01-19  2019-07-01         NaN         NaN         NaN
# 9       22-05-19  2019-05-22  2019-05-22  2019-05-22  2019-05-22
# 10    07/17/2019  2019-07-17  2019-07-17  2019-07-17  2019-07-17
# 11      07-02-19  2019-07-02  2019-07-02  2019-07-02  2019-07-02
# 12      02-08-15  2015-02-08         NaN         NaN         NaN
# 13     22-Jul-19  2019-07-22         NaN         NaN         NaN
# 14    07/22/2019  2019-07-22         NaN         NaN         NaN
# 15      06-07-19  2019-06-07         NaN         NaN         NaN
# 16     5/24/2019  2019-05-24  2019-05-24  2019-05-24  2019-05-24
# 17       4/15/16  2016-04-15         NaN  2016-04-15  2016-04-15
# 18      20-07-19  2019-07-20  2019-07-20  2019-07-20  2019-07-20
# 19     5/20/2019  2019-05-20  2019-06-20  2019-06-20  2019-06-20
# 20     29-May-19  2019-05-29  2019-05-29  2019-05-29  2019-05-29
# 21    22.05.2019  2019-11-22         NaN         NaN         NaN
# 22      05-07-19  2019-05-07         NaN         NaN         NaN
# 23      18-06-19  2019-06-18         NaN         NaN         NaN
# 24     28-Jun-19  2019-06-28  2013-06-28  2013-06-28  2013-06-28
# 25     03-Jun-19  2019-06-03  2019-06-03  2019-06-03  2019-06-03
# 26      06/20/19  2019-06-20  2019-06-20  2019-06-20  2019-06-20
# 27      04-10-19  2019-04-10  2019-07-12  2019-07-12  2019-07-12
# 28     07-Jun-19  2019-06-07  2019-06-07  2019-06-07  2019-06-07
# 29     6/28/2019  2019-06-28  2019-06-28  2019-06-28  2019-06-28
# 30      30-04-19  2019-04-30  2019-04-30  2019-04-30  2019-04-30
# 31      25-07-19  2019-07-25         NaN         NaN         NaN
# 32      03-10-17  2017-03-10         NaN         NaN         NaN
# 33      06-08-19  2019-06-08  2019-06-08  2019-06-08  2019-06-08
# 34      14-07-19  2019-07-14  2019-07-14  2019-07-14  2019-07-14
# 35     30-Jun-18  2018-06-30  2018-06-30  2018-06-30  2018-06-30
# 36      06/27/19  2019-06-27  2019-06-27  2019-06-27  2019-06-27
# 37    06/25/2019  2019-06-25         NaN         NaN         NaN
# 38     24-Nov-16  2016-11-24  2016-11-24  2016-11-24  2016-11-24
# 39           NaN         NaN         NaN         NaN         NaN

# %%
raw['predicted'] = None

# %%
def globalfindingdate(path):
    config = ("-l eng --oem 1 --psm 3")
    gaussian_filter = (3,3)
    img = cv2.imread(path) 
    img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)
    img_str_2 = pt.image_to_string(Image.fromarray(img_blur),lang ="eng",config=config)
    img_str_2 = list(set(map(lambda x : x.strip(), img_str_2.split('\n'))))
    date = finding_date(img_str_2)
    if date:
        print('First: ',date)
        return date
    
    img_str_1 = pt.image_to_string(path, lang='eng',config=config)
    img_str_1 = list(set(map(lambda x : x.strip(), img_str_1.split('\n'))))
    date = finding_date(img_str_1)
    if date:
        print('Second: ',date)
        return date 
    
    ret,th1 = cv2.threshold(img_blur, 100, 225, cv2.THRESH_BINARY)
    img_str_4 = pt.image_to_string(Image.fromarray(th1), lang = 'eng',config=config)
    img_str_4 = list(set(map(lambda x : x.strip(), img_str_4.split('\n'))))
    date = finding_date(img_str_4)
    if date:
        print('Third: ',date)
        return date 
    
    img_ad_thres = cv2.adaptiveThreshold(img_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    img_str_3 = pt.image_to_string(Image.fromarray(img_ad_thres),lang='eng',config=config)
    img_str_3 = list(set(map(lambda x : x.strip(), img_str_3.split('\n'))))
    date = finding_date(img_str_3)
    if date:
        print('Forth: ',date)
        return date 
    print('[]')
    return None

# %%
def globalpreprocess(path):
    
    img_str_1 = pt.image_to_string(path, lang='eng')
    
    gaussian_filter = (3,3)
    img = cv2.imread(path) 
    img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)
    img_str_2 = pt.image_to_string(Image.fromarray(img_blur),lang ="eng")
    
    #img_ad_thres = cv2.adaptiveThreshold(img_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    #img_str_3 = pt.image_to_string(Image.fromarray(img_ad_thres),lang='eng')

    #ret,th1 = cv2.threshold(img_blur, 100, 225, cv2.THRESH_BINARY)
    #img_str_4 = pt.image_to_string(Image.fromarray(th1), lang = 'eng')

    return [img_str_1,img_str_2]

# %%
path = 'images/91.jpeg'
globalfindingdate(path)

# %%
z =list(set(map(lambda x: x.strip(),ll[0].split('\n'))))

finding_date(z)

# %%
raw['predicted_3'] = None

# %%
for i in raw[raw.converted.notnull()].index:
    path = "images/" + str(i+1) + ".jpeg"
    print(i+1,end='  ')
    date = globalfindingdate(path)
    raw.loc[i,'predicted_3'] = date

# %%
val = (raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).values
ind = (raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).index

# %%
print((raw.converted == raw.predicted).value_counts())
print((raw.converted == raw.predicted_2).value_counts())
print((raw.converted == raw.predicted_3).value_counts())

# %%
(54/86)*100

# %% [markdown]
# # 4th attempt 63% accuracy

# %%
for i,j in enumerate(val):
    if not j:
        print(ind[i])

# %%
print((raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).value_counts())
print((raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted_2).value_counts())

# %%
(54/86)*100

# %% [markdown]
# # 3rd attempt accuracy is 60%

# %%
path = "images/1.jpeg"
gaussian_filter = (3,3)
img = cv2.imread(path) 
image = cv2.resize(img, None, fx = 2, fy = 2, interpolation=cv2.INTER_CUBIC) 
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, gaussian_filter, 0)
edged = cv2.Canny(blurred, 0, 50)
(contours, _) = cv2.findContours(edged, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours = sorted(contours, key=cv2.contourArea, reverse=True)
for c in contours:
    p = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * p, True)

    if len(approx) == 4:
        target = approx
        break

# %%
edged = cv2.Canny(img_thres, 0, 50)
(contours, _) = cv2.findContours(edged, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours = sorted(contours, key=cv2.contourArea, reverse=True)
for c in contours:
    p = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * p, True)

    if len(approx) == 4:
        target = approx
        break

# %%
Image.fromarray(edged)
# Out:
# <PIL.Image.Image image mode=L size=2160x2880 at 0x2B32BB14D68>

# %%
imz = Image.fromarray(ip.four_point_transform(img_gauss,target.reshape(4,2)))

# %%
imz
# Out:
# <PIL.Image.Image image mode=L size=10x44 at 0x2B330135E80>

# %%
print(pt.image_to_string(Image.fromarray(ip.four_point_transform(blurred,target.reshape(4,2)))))

# %%
print(pt.image_to_string(Image.fromarray(img_blur)))

# %%
ret,th1 = cv2.threshold(np.array(imz),100,225,cv2.THRESH_BINARY)
#print(pt.image_to_string(Image.fromarray(th1), lang = 'eng'))
Image.fromarray(th1)
# Out:
# <PIL.Image.Image image mode=L size=475x494 at 0x2B32BB6A6D8>

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-711e5dd93a37> in <module>()
# ----> 1 raw.head()
#
# NameError: name 'raw' is not defined
