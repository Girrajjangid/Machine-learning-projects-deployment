# %% [markdown]
# # Preprocessing terms
#
# 1. Scaling to the right size
# 2. Increase contrast
# 3. Binarize image
# 4. remove noise and scanning artefacts (black border)
# 5. Deskew
# 6. Remove border

# %%
import re
import cv2
import glob
import imutils
import tempfile
import operator
import argparse
import dateparser
import numpy as np
import pandas as pd
from PIL import Image
import pytesseract as pt
from imutils import contours
from collections import Counter
from datefinder import find_dates
from dateutil.parser import parse
from matplotlib import pyplot as plt
from scipy.spatial import distance as dist
from dateparser.search import search_dates
import imutils.perspective as ip
pt.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %%
def spread(arg):
    ret = []
    for i in arg:
        if isinstance(i, list):
            ret.extend(i)
        else:
            ret.append(i)
    return ret

def deep_flatten(lst):
    result = []
    result.extend(spread(list(map(lambda x: deep_flatten(x) if type(x) == list else x, lst))))
    return result

# %%
def finding_date(img_str):
    
    imstr = img_str
    pattern1 = r"(\d{1,4}([.'’~;\-/])\d{1,2}([.'’~;\-/])\d{1,4})"
    pattern2 = r"(\d{1,4}([.'’~\-/\s])[ADFJMNOSadfjmnos]\w*([.'’~\-/\s]*)\d{1,4})"
    pattern3 = r"([ADFJMNOSadfjmnos]\w*\s\d{1,4}([,'’.~\-/\s]*)([.'’~\-/\s])\d{1,4})"
    pattern4 = r"[ADFJMNOSadfjmnos]\w*\d{1,4}(['’]*)\d{1,4}"
    pattern5 = r"(\d{1,4}([.'’~\-/\s])\d{1,4}"
    
    date_find = []

    for i in imstr:
        for j in (re.search(regex,i) for regex in [pattern1, pattern2, pattern3, pattern4]):
            if j:
                s = j.group()
                if s.find('.') or s.find(';'):
                    date_find.append("-".join(s.split('.')))
                else:
                    date_find.append(s)

    date_find = list(set(date_find))

    dates = []
    for i in date_find:
        try:
            i = i.replace("’","'")
            i = i.replace("’’","'")
            i = i.replace('"',"'")
            i = i.replace('~',"-")
            i = parse(i).strftime("%Y-%m-%d")
            if 1999 < int(i[:4]) < 2020:
                dates.append(i)   
        except:
            continue
    
    d = {}
    if dates:
        #l = dict(Counter(dates))
        #date = max(l.items(), key=operator.itemgetter(1))[0]
        return dates
    else:
        return None

# %% [markdown]
# # Instead of feeding single input image with pre-process.
# # Now, I'm going to feed more than 4 same image with differently pre-processed.Also called Stacking technique

# %%
img_str = list(set(map(lambda x : x.strip(), ll[0].split('\n'))))
img_str
# Out:
# ['',
#  '1 Thai Fried Rice $12.00',
#  'ORDER: SECOND FLOOR 19',
#  'Total $69.79',
#  '1 Naan $3.00',
#  'Subtotal $56.00',
#  '2019840709',
#  '1 Mango Lassi $4.00',
#  '1 Chicken Tikka Masala $16.00',
#  'cashier: Kiran',
#  '103 MONTGOMERRY St',
#  'Dine-in',
#  '1 Vegetable Biryani $12.00',
#  'Tax $3.71',
#  'Med $0.00',
#  'Service Charge (18.0%) $10.08',
#  'Veyetables $0.00',
#  '24-Mar 2019 7:14:55P',
#  '1 Chicken Lollipop $9.00',
#  'NAANCHING',
#  'JERSEY CITY, NJ 07302',
#  'MILD PLEASE',
#  'MAKE IT MILD PLEASE']

# %%
path = 'images/433.jpeg'

# %%
ll = globalpreprocess(path)

# %%
print(ll[0])
# Out:
# NAANCHING
# 103 MONTGOMERRY St
# JERSEY CITY, NJ 07302
#
# 2019840709
#
# ORDER: SECOND FLOOR 19
# Dine-in
#
#
#
#
#
#
# cashier: Kiran
#
# 24-Mar 2019 7:14:55P
#
# 1 Chicken Lollipop $9.00
# Med $0.00
#
# 1 Thai Fried Rice $12.00
# Veyetables $0.00
# Med $0.00
#
# 1 Chicken Tikka Masala $16.00
# MILD PLEASE
#
# 1 Naan $3.00
# 1 Vegetable Biryani $12.00
# MAKE IT MILD PLEASE
#
# 1 Mango Lassi $4.00
# Subtotal $56.00
#
# Tax $3.71
# Service Charge (18.0%) $10.08
#
# Total $69.79

# %%
path = 'images/518.jpeg'
config = ("-l eng --oem 1 --psm 3")

# %%
# 1. Without any filter
print(pt.image_to_string(path, lang='eng', config = config))
# Out:
# NAANCHING
# 103 MONTGOMERRY St
# JERSEY CITY, NJ 07302
#
# 2019840709
#
# ORDER: SECOND FLOOR 19
# Dine-in
#
#
#
#
#
#
# cashier: Kiran
#
# 24-Mar 2019 7:14:55P
#
# 1 Chicken Lollipop $9.00
# Med $0.00
#
# 1 Thai Fried Rice $12.00
# Veyetables $0.00
# Med $0.00
#
# 1 Chicken Tikka Masala $16.00
# MILD PLEASE
#
# 1 Naan $3.00
# 1 Vegetable Biryani $12.00
# MAKE IT MILD PLEASE
#
# 1 Mango Lassi $4.00
# Subtotal $56.00
#
# Tax $3.71
# Service Charge (18.0%) $10.08
#
# Total $69.79

# %%
# 2. with filter
# image < resize < grayscale < gaussian 
gaussian_filter = (3,3)
img = cv2.imread(path) 
image = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, gaussian_filter, 0)
print(pt.image_to_string(Image.fromarray(blurred),lang = "eng", config = config))
# Out:
# NAANCHING
# 103 MONT GOMERRY Sl
# JERSEY CITY, NJ 07302
#
# 2019840709
#
# ORDER: SECOND FLOOR 19
# Dine-in
#
#
#
#
#
# cashier: Kiran
#
# 94-Mar-2019 7:14:55P
#
# 1 Chicken Lollipop $9.00
# Med $0.00
#
#
#
# 1 Thai Fried Rice $12.00
# Vegetables $0.00
# Med $0.00
#
# 1 Chicken Tikka Masala $16.00
# MILD PLEASE
#
# } Naan $3.00
# | Vegetable Biryani $12.00
# MAKE IT MILD PLEASE
#
#
#
#
# { Mango Lassi $4.00
#
# Subtotal $56.00
# Tax $3.71
# Service Charge (18.0%) $10.08
#
# Total $69.79

# %%
# 3. with filter
kernel = np.ones((2, 2), np.uint8)
img_dilate = cv2.dilate(gray, kernel, iterations=1)
img_erode = cv2.erode(img_dilate, kernel, iterations=1)
img_gauss = cv2.GaussianBlur(img_erode, gaussian_filter, 0)

# Thresholding
img_thres = cv2.adaptiveThreshold(img_gauss, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)

print(pt.image_to_string(Image.fromarray(img_thres),lang='eng', config = config))
# Out:
# Vrs ate
#
#  * Ubeaded cafe’.
# _- ° 45700 ‘Be. 1f:l Blv
# .  1Beltfl
#
# ‘Natha’:
#
# At
#
# 19
#
# tne.
#
# Enchi_Omelete:
#
# ED BEEF.
#
#  SHREDD
#
# a
#
# OED.
#
# fp EAS:
#
# Sid
#
# ‘SUBTOTAL
#
# 1

# %%
# 4. with filters
# image < resize < grayscale < gaussian < Binarization(threshold)
ret,th1 = cv2.threshold(img_thres,100,225,cv2.THRESH_BINARY)
ret2,th2 = cv2.threshold(img_thres,0,220,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#print(pt.image_to_string(Image.fromarray(th1), lang = 'eng', config = config))
Image.fromarray(th1)
# Out:
# <PIL.Image.Image image mode=L size=2250x3000 at 0x23829575198>

# %%
kernel = np.ones((5, 5), np.uint8)
img_dilate = cv2.dilate(th1, kernel, iterations=1)
img_erode = cv2.erode(img_dilate, kernel, iterations=1)
img_gauss = cv2.GaussianBlur(img_erode, gaussian_filter, 0)
print(pt.image_to_string(Image.fromarray(img_gauss)))
#Image.fromarray(img_gauss)
# Out:
# fw tats a .. ‘
# Co 4G "© qs” |. oT
# D2 mee oe < te nae OS: - —
# ‘ aati Noe
# Sannitic gd 33 o
# dec e ~ ee ey - t
# . i “ath. Pat Bese =
# tees TA Viele :
# ; SHEE: re
# 27 2 oe “ 4
# ! Sv : =, Maeeaes t . " “
# : n*. tu ahs ve
# Ce tea et Fes : a RE Ce ee"
# “73 rae) , Are
# ' Xa ,
#
#
#
#
#
#
# 00 Loaded care Blvd
# Bellfiower, CA.’ 90706
#
# 135 Nathalie
#
# Dine In
# 2 Enchi Omelete 6-25.98
# SHREDDED BEEF .. :-.-
# ” 1 Open Food at 3.19
# SHREDDED BEEG
# 1 Open Food | coon
# 1 Hashbrowns Side’ 2,99
# “1 Hashbrowns Side: 2.99
# {Coffee Hot . CO, 2.99.
# I ‘Diet. Coke ee 2,99
#
# SUBTOTAL : " 9 ih ae
# TAX A 44 32 oe
#
# _WSTAN TOTAL DUE
#
#
#
# } re
# es ee 7 an ye, raters fan rer r=
#
# tet " ie ‘7 ahs eae Eee
# He nik ede: e: 72 eto Kaper iy

# %%
def save_df(df):
    df.to_csv('image_data.csv',header=True,index=False)

# %%
save_df(data)

# %%
raw = pd.read_csv('image_data.csv')

# %%
raw.head(40)
# Out:
#           actual   converted   predicted predicted_2 predicted_3
# 0   May 21, 2019  2019-05-21         NaN         NaN         NaN
# 1       25-07-19  2019-07-25  2019-07-25  2019-07-25  2019-07-25
# 2   Sep 29, 2018  2018-09-29  2018-09-29  2018-09-29  2018-09-29
# 3      Oct06' 16  2016-10-06  2019-10-06         NaN  2019-10-06
# 4      5/29/2019  2019-05-29  2019-05-29  2019-05-29  2019-05-29
# 5    03/Jul/2019  2019-07-03  2019-07-03  2019-07-03  2019-07-03
# 6            NaN         NaN         NaN         NaN         NaN
# 7       23-05-19  2019-05-23         NaN         NaN         NaN
# 8       07-01-19  2019-07-01         NaN         NaN         NaN
# 9       22-05-19  2019-05-22  2019-05-22  2019-05-22         NaN
# 10    07/17/2019  2019-07-17  2019-07-17  2019-07-17  2019-07-17
# 11      07-02-19  2019-07-02  2019-07-02  2019-07-02  2013-07-02
# 12           NaN         NaN         NaN         NaN         NaN
# ...

# %%
raw['predicted'] = None

# %%
mode = raw.loc[:,['predicted','predicted_2','predicted_3']].mode(axis=1)

# %%
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 590    False
# 591    False
# 592     True
# 593    False
# 594     True
# Length: 595, dtype: bool

# %%
def globalfindingdate(filter_size,path):
    config = ("-l eng --oem 1 --psm 3")
    gaussian_filter = (filter_size,filter_size)
    img = cv2.imread(path) 
    img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)
    img_str_2 = pt.image_to_string(Image.fromarray(img_blur),lang ="eng",config=config)
    img_str_2 = list(set(map(lambda x : x.strip(), img_str_2.split('\n'))))
    date = finding_date(img_str_2)
    if date:
        print('First: ',date)
        return date
    
    img_str_1 = pt.image_to_string(path, lang='eng',config=config)
    img_str_1 = list(set(map(lambda x : x.strip(), img_str_1.split('\n'))))
    date = finding_date(img_str_1)
    if date:
        print('Second: ',date)
        return date 
    
    ret,th1 = cv2.threshold(img_blur, 100, 225, cv2.THRESH_BINARY)
    img_str_4 = pt.image_to_string(Image.fromarray(th1), lang = 'eng',config=config)
    img_str_4 = list(set(map(lambda x : x.strip(), img_str_4.split('\n'))))
    date = finding_date(img_str_4)
    if date:
        print('Third: ',date)
        return date 
    
    img_ad_thres = cv2.adaptiveThreshold(img_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    img_str_3 = pt.image_to_string(Image.fromarray(img_ad_thres),lang='eng',config=config)
    img_str_3 = list(set(map(lambda x : x.strip(), img_str_3.split('\n'))))
    date = finding_date(img_str_3)
    if date:
        print('Forth: ',date)
        return date 
    print('[]')
    return None

# %%
def globalpreprocess(path):
    
    img_str_1 = pt.image_to_string(path, lang='eng')
    
    gaussian_filter = (3,3)
    img = cv2.imread(path) 
    img = cv2.resize(img, None, fx = 3, fy = 3, interpolation=cv2.INTER_CUBIC) 
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img_blur = cv2.GaussianBlur(img_gray, gaussian_filter, 0)
    img_str_2 = pt.image_to_string(Image.fromarray(img_blur),lang ="eng")
    
    #img_ad_thres = cv2.adaptiveThreshold(img_blur, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    #img_str_3 = pt.image_to_string(Image.fromarray(img_ad_thres),lang='eng')

    #ret,th1 = cv2.threshold(img_blur, 100, 225, cv2.THRESH_BINARY)
    #img_str_4 = pt.image_to_string(Image.fromarray(th1), lang = 'eng')

    return [img_str_1,img_str_2]

# %%
path = 'images/2.jpeg'
globalfindingdate(path)

# %%
z =list(set(map(lambda x: x.strip(),ll[0].split('\n'))))

finding_date(z)

# %%
raw['predicted_4'] = None

# %% [markdown]
# # prediction

# %%
data['predicted_3'] = None

# %%
path = "images/2.jpeg"
l = [3,5,7]
for i in l:
    date = globalfindingdate(i,path)
    print(date)
# Out:
# Second:  ['2019-07-25']
# ['2019-07-25']
# First:  ['2019-07-25']
# ['2019-07-25']
# First:  ['2019-07-25']
# ['2019-07-25']

# %%
raw.tail(40)
# Out:
#               actual   converted   predicted predicted_2 predicted_3
# 555       17-06-2019  2019-06-17  2019-04-17  2019-04-17  2019-04-17
# 556        8/30/2015  2015-08-30  2015-08-30  2015-08-30  2015-08-30
# 557        29-6-2019  2019-06-29  2002-04-01  2002-04-01  2002-04-01
# 558         02/28/19  2019-02-28  2019-02-28  2019-02-28  2019-02-28
# 559         04/27/19  2019-04-27         NaN         NaN         NaN
# 560         12-03-19  2019-12-03  2019-12-03  2019-12-03  2019-12-03
# 561        21-May-19  2019-05-21  2019-08-21  2019-08-21  2019-08-21
# 562       22/05/2019  2019-05-22  2019-04-09  2019-04-09         NaN
# 563       10/25/2018  2018-10-25  2018-10-25  2018-10-25  2018-10-25
# 564       06/05/2019  2019-06-05  2019-06-08  2019-06-05  2019-02-05
# 565         06/24/19  2019-06-24  2019-06-24  2019-06-24  2019-06-24
# 566         06/11/19  2019-06-11         NaN         NaN         NaN
# 567         Sep30'17  2017-09-30         NaN         NaN         NaN
# ...

# %%
for i in raw.converted[raw.converted.notnull()].index[-30:]:
    path = "images/" + str(i) + ".jpeg"
    print(i,end='  ')
    date = globalfindingdate(path)
    raw.loc[i,'predicted_4'] = date
# Out:
# 563  []
# 564  First:  2018-10-25
# 565  First:  2019-02-05
# 566  Second:  2019-06-24
# 567  []
# 568  []
# 569  First:  2018-08-28
# 570  First:  2019-07-23
# 571  Third:  2019-06-17
# 572  []
# 573  Third:  2019-05-06
# 574  Forth:  2019-07-05
# 575  []
# 576  []
# 577  First:  2019-05-17
# 578  First:  2019-02-01
# 579  []
# 580  First:  2019-04-28
# 581  []
# 582  First:  2006-05-09
# 583  Third:  2019-08-16
# 584  Second:  2019-06-25
# 585  First:  2019-04-10
# 587  First:  2019-01-11
# 588  First:  2018-06-29
# 589  First:  2018-01-30
# 590  First:  2012-09-12
# 593  Third:  2014-10-21
# 594  []
# 595  []

# %%
raw.tail(30)
# Out:
#               actual   converted   predicted predicted_2 predicted_3  \
# 566         06/24/19  2019-06-24  2019-06-24  2019-06-24  2019-06-24
# 567         06/11/19  2019-06-11         NaN         NaN         NaN
# 568         Sep30'17  2017-09-30         NaN         NaN         NaN
# 569       28-08-2018  2018-08-28  2018-08-28  2018-08-28  2018-08-28
# 570      23-Jul-2019  2019-07-23  2019-07-01  2019-07-23  2019-07-01
# 571       06/17/2019  2019-06-17  2019-06-17  2019-06-17  2019-06-17
# 572      01-JUL-2017  2017-07-01         NaN         NaN         NaN
# 573         6/6/2019  2019-06-06  2019-06-06  2019-05-06  2019-05-06
# 574         29/05/19  2019-05-29  2019-05-29  2018-05-29  2019-05-29
# 575         07/28/18  2018-07-28         NaN  2018-07-28  2018-07-28
# 576         16Feb'19  2019-02-16         NaN         NaN         NaN
# 577         05/17/19  2019-05-17  2019-05-17  2019-05-17  2019-05-17
# 578         6/1/2013  2013-06-01  2019-01-02  2019-01-02  2019-01-02
# ...

# %%
val = (raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).values
ind = (raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).index

# %%
print((raw.converted == raw.predicted).value_counts())
print((raw.converted == raw.predicted_2).value_counts())
print((raw.converted == raw.predicted_3).value_counts())
print((raw.converted == raw.loc[:,['predicted','predicted_2','predicted_3']].mode(axis=1)[0]).value_counts())
# Out:
# True     317
# False    278
# dtype: int64
# True     330
# False    265
# dtype: int64
# True     336
# False    259
# dtype: int64
# True     353
# False    242
# dtype: int64

# %% [markdown]
# #  6th attempt on whole dates accuracy 66%

# %%
#save_df(data)
pd.rea
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-2e5459ea4502> in <module>()
#       1 #save_df(data)
# ----> 2 data
#
# NameError: name 'data' is not defined

# %%
(353/516)*100
# Out:
# 68.4108527131783

# %%
(330/516)*100
# Out:
# 63.95348837209303

# %%
(317/516)*100
# Out:
# 61.434108527131784

# %% [markdown]
# # 5th attempt on whole dates accuracy 62%

# %%
(54/86)*100

# %% [markdown]
# # 4th attempt 63% accuracy

# %%
for i,j in enumerate(val):
    if not j:
        print(ind[i])

# %%
print((raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted).value_counts())
print((raw[raw.converted.notnull()].converted ==  raw[raw.converted.notnull()].predicted_2).value_counts())

# %%
(54/86)*100

# %% [markdown]
# # 3rd attempt accuracy is 60%

# %%
path = "images/470.jpeg"
gaussian_filter = (5,5)
img = cv2.imread(path) 
image = cv2.resize(img, None, fx = 1.5, fy = 1.5, interpolation=cv2.INTER_CUBIC) 
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, gaussian_filter, 0)
edged = cv2.Canny(blurred, 0, 50)
(contours, _) = cv2.findContours(edged, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours = sorted(contours, key=cv2.contourArea, reverse=True)
for c in contours:
    p = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * p, True)

    if len(approx) == 4:
        target = approx
        break

# %%
edged = cv2.Canny(img_thres, 0, 50)
(contours, _) = cv2.findContours(edged, cv2.RETR_LIST, cv2.CHAIN_APPROX_NONE)
contours = sorted(contours, key=cv2.contourArea, reverse=True)
for c in contours:
    p = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * p, True)

    if len(approx) == 4:
        target = approx
        break

# %%
Image.fromarray(edged)
# Out:
# <PIL.Image.Image image mode=L size=2250x3000 at 0x23829CF26D8>

# %%
imz = Image.fromarray(ip.four_point_transform(img_gauss,target.reshape(4,2)))

# %%
imz
# Out:
# <PIL.Image.Image image mode=L size=2133x2134 at 0x23829CF2A90>

# %%
print(pt.image_to_string(Image.fromarray(ip.four_point_transform(blurred,target.reshape(4,2)))))

# %%
print(pt.image_to_string(Image.fromarray(img_blur)))

# %%
ret,th1 = cv2.threshold(np.array(imz),100,225,cv2.THRESH_BINARY)
#print(pt.image_to_string(Image.fromarray(th1), lang = 'eng'))
Image.fromarray(th1)
# Out:
# <PIL.Image.Image image mode=L size=475x494 at 0x2B32BB6A6D8>

# %% [markdown]
# # Load dataset

# %%
def load_dataset():
    with open("all_image_dates.txt") as file:
        data = file.read()
    data = pd.DataFrame(data.replace(';','').split('\n'),index = range(1,596),columns = ['actual'])
    data['converted'] = None
    for i in data.actual[data.actual != 'null'].items():
        data.loc[i[0],'converted'] = parse(i[1]).strftime('%Y-%m-%d')    
    return data

# %%
data = load_dataset()

# %%
data.head()
# Out:
#          actual   converted
# 1  May 21, 2019  2019-05-21
# 2      25-07-19  2019-07-25
# 3  Sep 29, 2018  2018-09-29
# 4     Oct06' 16  2016-10-06
# 5     5/29/2019  2019-05-29
