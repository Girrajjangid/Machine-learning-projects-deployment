# %%
import numpy as np

# %%
img = "data:image/png;base64,..."

# %%
imgcss = "url('data:image/png;base64,...')"

# %%
import base64
import copy

# %%
import base64
from PIL import Image
from io import BytesIO

with open("a.png", "rb") as image_file:
    data = base64.b64encode(image_file.read())

im = Image.open(BytesIO(base64.b64decode(data)))
im.save('image1.png', 'PNG')

# %%
z = img.split(',')

# %%
Image.open(BytesIO(base64.b64decode(img[22:])))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=424x654 at 0x2A265E27A20>

# %%
data
# Out:
# b'...'

# %%
b64_string = copy.copy(img)

# %%
b64_string += '=' * (-len(b64_string) % 4)  # restore stripped '='s

# %%
base64.b64decode()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-2fed8ced82fc> in <module>
# ----> 1 base64.b64decode()
#
# TypeError: b64decode() missing 1 required positional argument: 's'

# %%
b64_string += "=" * ((4 - len(b64_string) % 4) % 4) #ugh
#string = b'{b64_string}'
with open("imageToSave.png", "wb") as fh:
    fh.write(base64.decodebytes(b64_string.encode()))
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# <ipython-input-42-d8d2e4e44a1c> in <module>
#       2 #string = b'{b64_string}'
#       3 with open("imageToSave.png", "wb") as fh:
# ----> 4     fh.write(base64.decodebytes(b64_string.encode()))
#
# ~\Anaconda3\envs\python_gpu\lib\base64.py in decodebytes(s)
#     551     """Decode a bytestring of base-64 data into a bytes object."""
#     552     _input_type_check(s)
# --> 553     return binascii.a2b_base64(s)
#     554
#     555 def decodestring(s):
#
# Error: Invalid base64-encoded string: length cannot be 1 more than a multiple of 4

# %%
from PIL import Image
from base64 import decodestring

image = Image.fromstring('RGB',(500,500),decodestring(img))
image.save("foo.png")
# Out:
# C:\Users\GirrajJangid\Anaconda3\envs\python_gpu\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: decodestring() is a deprecated alias since Python 3.1, use decodebytes()
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\python_gpu\lib\base64.py in _input_type_check(s)
#     516     try:
# --> 517         m = memoryview(s)
#     518     except TypeError as err:
#
# TypeError: memoryview: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-e80855f67114> in <module>
#       2 from base64 import decodestring
#       3
# ----> 4 image = Image.fromstring('RGB',(500,500),decodestring(img))
#       5 image.save("foo.png")
#
# ...

# %%
fh = open("newimage.png",'w')

# %%
fh.writelines(base64.decodestring(img))
# Out:
# C:\Users\GirrajJangid\Anaconda3\envs\python_gpu\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: decodestring() is a deprecated alias since Python 3.1, use decodebytes()
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\envs\python_gpu\lib\base64.py in _input_type_check(s)
#     516     try:
# --> 517         m = memoryview(s)
#     518     except TypeError as err:
#
# TypeError: memoryview: a bytes-like object is required, not 'str'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3e6c2490721f> in <module>
# ----> 1 fh.writelines(base64.decodestring(img))
#
# ~\Anaconda3\envs\python_gpu\lib\base64.py in decodestring(s)
#     559                   "use decodebytes()",
# ...

# %%
from PIL import Image

# %%
Image.open('imageToSave.png')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-b39d2bfc6c93> in <module>
# ----> 1 Image.open('imageToSave.png')
#
# ~\Anaconda3\envs\python_gpu\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2703         warnings.warn(message)
#    2704     raise IOError("cannot identify image file %r"
# -> 2705                   % (filename if filename else fp))
#    2706
#    2707 #
#
# OSError: cannot identify image file 'imageToSave.png'

# %%
plain import base64 image = open('deer.gif', 'rb') #open binary file in read mode image_read = image.read() image_64_encode = base64.encodestring(image_read)
